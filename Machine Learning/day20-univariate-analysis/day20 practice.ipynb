# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
 df = pd.read_csv('deliveries.csv')

# %%
dfnew = df.iloc[ :100 , :]

# %%
dfnew
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ..       ...     ...                  ...                          ...   ...
# 95         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    16
# 96         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    16
# 97         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    16
# 98         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    16
# 99         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
#
# ...

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          100 non-null    int64
#  1   inning            100 non-null    int64
#  2   batting_team      100 non-null    object
#  3   bowling_team      100 non-null    object
#  4   over              100 non-null    int64
#  5   ball              100 non-null    int64
#  6   batsman           100 non-null    object
#  7   non_striker       100 non-null    object
#  8   bowler            100 non-null    object
#  9   is_super_over     100 non-null    int64
#  10  wide_runs         100 non-null    int64
#  11  bye_runs          100 non-null    int64
#  12  legbye_runs       100 non-null    int64
#  13  noball_runs       100 non-null    int64
#  14  penalty_runs      100 non-null    int64
#  15  batsman_runs      100 non-null    int64
# ...

# %%
sns.countplot(x="batsman", data=dfnew)
# Out:
# <Axes: xlabel='batsman', ylabel='count'>

# %%
sns.countplot(x="non_striker", data=dfnew)
# Out:
# <Axes: xlabel='non_striker', ylabel='count'>

# %%
sns.countplot(x="bowler", data=dfnew)
# Out:
# <Axes: xlabel='bowler', ylabel='count'>

# %%
dfnew['bowler'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
dfnew['batting_team'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
dfnew['player_dismissed'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['is_super_over'],bins=5)
# Out:
# (array([1.50379e+05, 0.00000e+00, 0.00000e+00, 0.00000e+00, 8.10000e+01]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['ball'])
# Out:
# (array([24397., 24330., 24261., 24202.,     0., 24123., 24041.,  4324.,
#           679.,   103.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['total_runs'])
# Out:
# <Axes: ylabel='total_runs'>

# %%
df.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...
