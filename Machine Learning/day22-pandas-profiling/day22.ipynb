# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in e:\programing\python\app\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (3.8.4)
# Requirement already satisfied: pydantic>=1.8.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (2.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (2.1.3)
# Requirement already satisfied: visions==0.7.4 in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.2 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in e:\programing\python\app\lib\site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in e:\programing\python\app\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in e:\programing\python\app\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.2.1)
# Requirement already satisfied: imagehash in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programing\python\app\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\programing\python\app\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.6.2)
# Requirement already satisfied: colorama in e:\programing\python\app\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in e:\programing\python\app\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in e:\programing\python\app\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)

# %%
# !pip install pandas-profiling[notebook]
# Out:
# Requirement already satisfied: pandas-profiling[notebook] in e:\programing\python\app\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (3.8.4)
# Requirement already satisfied: pydantic>=1.8.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (2.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (2.1.3)
# Requirement already satisfied: visions==0.7.4 in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.2 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (1.12)
# Requirement already satisfied: jupyter-client>=5.3.4 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (8.6.0)
# Requirement already satisfied: jupyter-core>=4.6.3 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (5.7.2)
# Requirement already satisfied: ipywidgets>=7.5.1 in e:\programing\python\app\lib\site-packages (from pandas-profiling[notebook]) (7.8.1)
# Requirement already satisfied: attrs>=19.3.0 in e:\programing\python\app\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in e:\programing\python\app\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (3.2.1)
# Requirement already satisfied: imagehash in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (4.3.1)
# Requirement already satisfied: Pillow in e:\programing\python\app\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (10.3.0)
# Requirement already satisfied: comm>=0.1.3 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in e:\programing\python\app\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programing\python\app\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in e:\programing\python\app\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in e:\programing\python\app\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (6.4.1)
# Requirement already satisfied: platformdirs>=2.5 in e:\programing\python\app\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in e:\programing\python\app\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (305.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\programing\python\app\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in e:\programing\python\app\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[notebook]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\programing\python\app\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[notebook]) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[notebook]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[notebook]) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\programing\python\app\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[notebook]) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\programing\python\app\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2024.6.2)
# Requirement already satisfied: colorama in e:\programing\python\app\lib\site-packages (from tqdm>=4.48.2->pandas-profiling[notebook]) (0.4.6)
# Requirement already satisfied: decorator in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.1)
# Requirement already satisfied: matplotlib-inline in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six>=1.5 in e:\programing\python\app\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in e:\programing\python\app\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.0.8)
# Requirement already satisfied: PyWavelets in e:\programing\python\app\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (1.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in e:\programing\python\app\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.3)
# Requirement already satisfied: wcwidth in e:\programing\python\app\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: executing in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: ipykernel in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.2.0)
# Requirement already satisfied: babel>=2.10 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.19.2)
# Requirement already satisfied: sniffio>=1.1 in e:\programing\python\app\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in e:\programing\python\app\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.2.1)
# Requirement already satisfied: fastjsonschema in e:\programing\python\app\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.16.2)
# Requirement already satisfied: debugpy>=1.6.5 in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.6.7)
# Requirement already satisfied: nest-asyncio in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.9.0)
# Requirement already satisfied: webencodings in e:\programing\python\app\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook])
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook])
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook])
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook])
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in e:\programing\python\app\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in e:\programing\python\app\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.5)
# Requirement already satisfied: pycparser in e:\programing\python\app\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in e:\programing\python\app\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.2.3)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 uri-template-1.3.0 webcolors-24.11.1
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /packages/cf/58/8acf1b3e91c58313ce5cb67df61001fc9dcd21be4fadb76c1a2d540e09ed/fqdn-1.5.1-py3-none-any.whl.metadata

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in e:\programing\python\app\lib\site-packages (7.8.1)
# Requirement already satisfied: comm>=0.1.3 in e:\programing\python\app\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in e:\programing\python\app\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in e:\programing\python\app\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in e:\programing\python\app\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in e:\programing\python\app\lib\site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in e:\programing\python\app\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in e:\programing\python\app\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: notebook>=4.4.1 in e:\programing\python\app\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in e:\programing\python\app\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in e:\programing\python\app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.1)
# Requirement already satisfied: wcwidth in e:\programing\python\app\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in e:\programing\python\app\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.2)
# Requirement already satisfied: prometheus-client>=0.9 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in e:\programing\python\app\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: ipykernel in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in e:\programing\python\app\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: babel>=2.10 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.19.2)
# Requirement already satisfied: requests>=2.31 in e:\programing\python\app\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.2)
# Requirement already satisfied: six in e:\programing\python\app\lib\site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets) (1.16.0)
# Requirement already satisfied: idna>=2.8 in e:\programing\python\app\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in e:\programing\python\app\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in e:\programing\python\app\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in e:\programing\python\app\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\programing\python\app\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in e:\programing\python\app\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programing\python\app\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in e:\programing\python\app\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in e:\programing\python\app\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.1)
# Requirement already satisfied: rfc3339-validator in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in e:\programing\python\app\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: defusedxml in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in e:\programing\python\app\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in e:\programing\python\app\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\programing\python\app\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\programing\python\app\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\programing\python\app\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2024.6.2)
# Requirement already satisfied: debugpy>=1.6.5 in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in e:\programing\python\app\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: webencodings in e:\programing\python\app\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Requirement already satisfied: fqdn in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Requirement already satisfied: uri-template in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in e:\programing\python\app\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in e:\programing\python\app\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in e:\programing\python\app\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in e:\programing\python\app\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in e:\programing\python\app\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.2.3)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run script server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File E:\programing\Python\APP\Lib\site-packages\pandas_profiling\__init__.py:8
#       5 import importlib.util
#       6 from warnings import warn
# ----> 8 from ydata_profiling.compare_reports import compare
#       9 from ydata_profiling.controller import pandas_decorator
#      10 from ydata_profiling.profile_report import ProfileReport
#
# File E:\programing\Python\APP\Lib\site-packages\ydata_profiling\__init__.py:14
#      10 warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      12 import importlib.util  # isort:skip # noqa
# ---> 14 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      15 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      16 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File E:\programing\Python\APP\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File E:\programing\Python\APP\Lib\site-packages\ydata_profiling\profile_report.py:25
#      23 from tqdm.auto import tqdm
#      24 from typeguard import typechecked
# ---> 25 from visions import VisionsTypeset
#      27 from ydata_profiling.config import Config, Settings, SparkSettings
#      28 from ydata_profiling.expectations_report import ExpectationsReport
#
# File E:\programing\Python\APP\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File E:\programing\Python\APP\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'
