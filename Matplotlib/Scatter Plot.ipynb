# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[2,3,5,6,7,8,9]
y2=[34,23,12,44,76,87,34]
# c=["r","g","y","b","g","g","y"]
colors=[12,23,45,67,89,43,65]

sizes=[100,120,130,230,140,150,250]
plt.xlabel("Value1", fontsize=20)
plt.ylabel("Value2", fontsize=10)
plt.title("Scatter Plot", fontsize=15)

# alpha character used in plot scatter
# plt.scatter(x,y,color=c,s=sizes,alpha=0.45,marker="*",edgecolor="g")

# plt.scatter(x,y,color=c,s=sizes,marker="*",edgecolor="g",linewidth=2)


#These all are different colorMaps and all should in their reverse formate is "PRGn_r" 
# plt.scatter(x,y,c=colors,s=sizes,cmap="viridis")
# plt.scatter(x,y,c=colors,s=sizes,cmap="GnBu")
plt.scatter(x,y,c=colors,s=sizes,cmap="PRGn")
plt.scatter(x,y2,c=colors,s=sizes,cmap="PRGn")

t=plt.colorbar()
t.set_label("Color Bar")


plt.show()
