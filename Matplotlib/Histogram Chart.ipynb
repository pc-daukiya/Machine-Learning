# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [15 19 15 30 20 23 25 14 57 53 15 28 14 33 56 53 54 22 10 23 41 35 20 32
#  34 24 13 13 46 58 44 14 56 48 43 38 23 17 28 36 21 43 19 52 31 42 47 38
#  47 11]

# %%
no=[15, 19, 15, 30, 20, 23, 25, 14, 57, 53, 15, 28, 14, 33, 56, 53, 54, 22, 10, 23, 41, 35, 20 ,32,
 34, 24, 13, 13, 46, 58, 44, 14, 56, 48, 43, 38, 23, 17, 28, 36, 21, 43 ,19 ,52, 31, 42 ,47 ,38,
 47, 11]
# plt.hist(no, color="r", edgecolor="black")

l=[10,20,30,40,50,60]
# plt.hist(no, color="r",bins=l, edgecolor="black")

# plt.hist(no, color="r", edgecolor="black", cumulative=-1)

# plt.hist(no, color="r", edgecolor="black",bottom= 20 )

# plt.hist(no, bins=l, color="b", edgecolor="black",align="mid" )

# plt.hist(no, bins=l, color="b", edgecolor="black",histtype="step" )

# plt.hist(no, bins=l, color="b", edgecolor="black",histtype="stepfilled" )

# plt.hist(no, bins=l, color="b", edgecolor="black",histtype="barstacked" )

# plt.hist(no, bins=l, color="b", edgecolor="black",orientation="horizontal")

# plt.hist(no, bins=l, color="b", edgecolor="black",orientation="vertical", rwidth=0.8)

# plt.hist(no, bins=l, color="b", edgecolor="black",orientation="vertical", log=True)

plt.hist(no, bins=l, color="b", edgecolor="black",orientation="vertical",label="python" )





plt.title("Histogram Chart", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.axvline(45,color="r", label="xvline")

plt.legend()
plt.grid()
plt.show()
