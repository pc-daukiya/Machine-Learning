# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,5,6,7]

plt.plot(x,y)

# plt.xticks(x, labels=["python","c","c++","java","next.js"])
# plt.yticks(x)

# plt.xlim(0,10)
# plt.ylim(0,10)

plt.axis([0,10,0,7])

plt.show()
