# %%
import pandas as pd
import numpy as np

dict1 = {
    "name":['Prakash', 'Rohan', 'Skillf', 'Shubh'],
    "marks":[99, 65, 76, 79],
    "city":['Jodhpur', 'jaipur', 'raibarelly', 'Barmer']
}
# print(dict1)
df = pd.DataFrame(dict1)
df
# Out:
#       name  marks        city
# 0  Prakash     99     Jodhpur
# 1    Rohan     65      jaipur
# 2   Skillf     76  raibarelly
# 3    Shubh     79      Barmer

# %%
df.to_csv('friends.csv')

df.to_csv('friends_indexfalse.csv', index=False)

df.head(2)
# Out:
#       name  marks     city
# 0  Prakash     99  Jodhpur
# 1    Rohan     65   jaipur

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  Skillf     76  raibarelly
# 3   Shubh     79      Barmer

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   79.750000
# std    14.174508
# min    65.000000
# 25%    73.250000
# 50%    77.500000
# 75%    84.000000
# max    99.000000

# %%
prakash = pd.read_csv('prakash.csv')

# %%
prakash
# Out:
#   Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0  Train No  Speed        City
# 0          1st          1st        1st    234567    700     Jodhpur
# 1          2nd          2nd        2nd   1232345    656      jaipur
# 2          3rd          3rd        3rd   2237648    766  raibarelly
# 3          4th          4th        4th   4375308    795      Barmer

# %%
prakash['Speed'][0] = 700
# Out:
# C:\Users\praka\AppData\Local\Temp\ipykernel_5820\2944766241.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   prakash['Speed'][0] = 700
# ...

# %%
prakash
# Out:
#   Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0  Train No  Speed        City
# 0          1st          1st        1st    234567    700     Jodhpur
# 1          2nd          2nd        2nd   1232345    656      jaipur
# 2          3rd          3rd        3rd   2237648    766  raibarelly
# 3          4th          4th        4th   4375308    795      Barmer

# %%
prakash.to_csv('prakash.csv')

# %%
prakash.index = ['1st', '2nd', '3rd', '4th']

# %%
prakash
# Out:
#     Unnamed: 0.2 Unnamed: 0.1 Unnamed: 0  Train No  Speed        City
# 1st          1st          1st        1st    234567    700     Jodhpur
# 2nd          2nd          2nd        2nd   1232345    656      jaipur
# 3rd          3rd          3rd        3rd   2237648    766  raibarelly
# 4th          4th          4th        4th   4375308    795      Barmer

# %%
prakash.to_csv('prakash.csv')

# %%
ser = pd.Series(np.random.rand(34))
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# 0     0.192077
# 1     0.123088
# 2     0.981767
# 3     0.040284
# 4     0.391892
# 5     0.157656
# 6     0.444788
# 7     0.985851
# 8     0.063840
# 9     0.423480
# 10    0.959755
# 11    0.406616
# 12    0.379341
# 13    0.966775
# 14    0.678953
# 15    0.486025
# 16    0.862657
# 17    0.571625
# 18    0.794451
# 19    0.603563
# 20    0.136530
# 21    0.220736
# 22    0.785482
# 23    0.143615
# 24    0.298056
# 25    0.865876
# 26    0.432352
# 27    0.637548
# 28    0.784407
# 29    0.300750
# 30    0.167072
# 31    0.424276
# 32    0.992230
# 33    0.358985
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334,5))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.766143  0.715347  0.350820  0.627488  0.112986
# 1    0.535983  0.645726  0.309275  0.790733  0.026741
# 2    0.621363  0.300056  0.206298  0.555658  0.334059
# 3    0.293504  0.487008  0.428755  0.435965  0.021115
# 4    0.264943  0.011291  0.923604  0.777565  0.310504
# ..        ...       ...       ...       ...       ...
# 329  0.178204  0.117534  0.239296  0.627666  0.732513
# 330  0.667317  0.984582  0.422444  0.069868  0.945455
# 331  0.679188  0.660073  0.542026  0.531926  0.070640
# 332  0.446699  0.386021  0.304094  0.898532  0.933388
# 333  0.185026  0.776625  0.917699  0.172067  0.088441
#
# [334 rows x 5 columns]

# %%
newdf.to_csv('random.csv')

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
# %%
newdf.iloc[[0,5], [1,2]]
# Out:
#           B         C
# 0  0.715347  0.350820
# 5  0.245378  0.795712

# %%
newdf.drop(['A', 'C'], axis = 1)
# Out:
#             B         D         E
# 0    0.715347  0.627488  0.112986
# 1    0.645726  0.790733  0.026741
# 2    0.300056  0.555658  0.334059
# 3    0.487008  0.435965  0.021115
# 4    0.011291  0.777565  0.310504
# ..        ...       ...       ...
# 329  0.117534  0.627666  0.732513
# 330  0.984582  0.069868  0.945455
# 331  0.660073  0.531926  0.070640
# 332  0.386021  0.898532  0.933388
# 333  0.776625  0.172067  0.088441
#
# [334 rows x 3 columns]

# %%
newdf.drop([1, 2], axis = 0, inplace=True)

# %%
newdf
# Out:
#             B         D         E
# 0    0.715347  0.627488  0.112986
# 3    0.487008  0.435965  0.021115
# 4    0.011291  0.777565  0.310504
# 5    0.245378  0.340233  0.588071
# 6    0.354540  0.764232  0.706985
# ..        ...       ...       ...
# 329  0.117534  0.627666  0.732513
# 330  0.984582  0.069868  0.945455
# 331  0.660073  0.531926  0.070640
# 332  0.386021  0.898532  0.933388
# 333  0.776625  0.172067  0.088441
#
# [332 rows x 3 columns]

# %%
newdf.reset_index(drop=True,axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 newdf.reset_index(drop=True,axis=1, inplace=True)
#
# TypeError: DataFrame.reset_index() got an unexpected keyword argument 'axis'

# %%
newdf
# Out:
#             B         D         E
# 0    0.715347  0.627488  0.112986
# 1    0.487008  0.435965  0.021115
# 2    0.011291  0.777565  0.310504
# 3    0.245378  0.340233  0.588071
# 4    0.354540  0.764232  0.706985
# ..        ...       ...       ...
# 327  0.117534  0.627666  0.732513
# 328  0.984582  0.069868  0.945455
# 329  0.660073  0.531926  0.070640
# 330  0.386021  0.898532  0.933388
# 331  0.776625  0.172067  0.088441
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:, ['B']] = 23

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf
# Out:
#       B         D         E
# 0    23  0.627488  0.112986
# 1    23  0.435965  0.021115
# 2    23  0.777565  0.310504
# 3    23  0.340233  0.588071
# 4    23  0.764232  0.706985
# ..   ..       ...       ...
# 327  23  0.627666  0.732513
# 328  23  0.069868  0.945455
# 329  23  0.531926  0.070640
# 330  23  0.898532  0.933388
# 331  23  0.172067  0.088441
#
# [332 rows x 3 columns]

# %%
df = pd.DataFrame({
'Name': ['Nick', 'Nick', 'Krish'],
'Age': [np.nan, 21, 19],
'Born': [pd.Timestamp("2006-05-18"), pd.Timestamp("1940-05-25"), pd.NaT]})

# %%
df.head()
# Out:
#     Name   Age       Born
# 0   Nick   NaN 2006-05-18
# 1   Nick  21.0 1940-05-25
# 2  Krish  19.0        NaT

# %%
df.dropna()
# Out:
#    Name   Age       Born
# 1  Nick  21.0 1940-05-25

# %%
df.dropna(how='all', axis=1)
# Out:
#     Name   Age       Born
# 0   Nick   NaN 2006-05-18
# 1   Nick  21.0 1940-05-25
# 2  Krish  19.0        NaT

# %%
df.drop_duplicates(subset=['Name'])
# Out:
#     Name   Age       Born
# 0   Nick   NaN 2006-05-18
# 2  Krish  19.0        NaT

# %%
# df.drop_duplicates(subset=['Name'], keep='first')
# df.drop_duplicates(subset=['Name'], keep='last')
df.drop_duplicates(subset=['Name'], keep=False)
# Out:
#     Name   Age Born
# 2  Krish  19.0  NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     2 non-null      float64
#  2   Born    2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 204.0+ bytes

# %%
# df['Age'].value_counts(dropna=False)
# df['Age'].value_counts(dropna=True)
df['Age'].value_counts(dropna=False)
# Out:
# Age
# 21.0    1
# 19.0    1
# Name: count, dtype: int64

# %%
# df.isnull()
df.notnull()
# Out:
#    Name    Age   Born
# 0  True  False   True
# 1  True   True   True
# 2  True   True  False
